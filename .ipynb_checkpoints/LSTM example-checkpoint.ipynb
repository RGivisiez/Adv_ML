# %% [markdown]
# # RNN (LSTM) code, just a example.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from datetime import datetime

# %%
def parse(x):
    return datetime.strptime(x, '%Y %m %d %H')
df = read_csv('air_data.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)

# %%
df.drop('No', axis=1, inplace=True)
df.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
df.index.name = 'date'
df['pollution'].fillna(0, inplace=True)

# %%
df = df[25:]

# %%
plt.figure(figsize=(10,10))

columns = df.columns

for i, column in enumerate(columns):
    plt.subplot(len(columns), 1, i+1)
    plt.plot(df[column])
    plt.title(column, y=0.5, loc='right')

plt.show()

# %%
encoder = LabelEncoder()

# %%
a = encoder.fit_transform(df['wnd_dir'])
df.loc[:, 'wnd_dir'] = a
del a

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(df)
df = pd.DataFrame(scaled, columns = df.columns, index=df.index)
# Out:
# /home/ronaldo/anaconda3/envs/Data_Science/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
df.drop(['dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain'], axis=1, inplace=True)

# %%
def time_shift(df, lags):
    
    columns = df.columns
    
    for lag in lags:
        for column in columns:
            new_column = column + '_lag' + str(i)
            df[new_column] = df[column].shift(lag)
    
    return df

# %%
a = time_shift(df, [1, 2])

# %%
df.head()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 01:00:00   0.148893  0.367647  0.245902  0.527273  0.666667
# 2010-01-02 02:00:00   0.159960  0.426471  0.229508  0.545455  0.666667
# 2010-01-02 03:00:00   0.182093  0.485294  0.229508  0.563636  0.666667
# 2010-01-02 04:00:00   0.138833  0.485294  0.229508  0.563636  0.666667
# 2010-01-02 05:00:00   0.109658  0.485294  0.213115  0.563636  0.666667
#
#                       wnd_spd      snow  rain  pollutionlag7   dewlag7  \
# date
# 2010-01-02 01:00:00  0.003811  0.000000   0.0            NaN       NaN
# 2010-01-02 02:00:00  0.005332  0.000000   0.0            NaN       NaN
# 2010-01-02 03:00:00  0.008391  0.037037   0.0       0.148893  0.367647
# 2010-01-02 04:00:00  0.009912  0.074074   0.0       0.159960  0.426471
# 2010-01-02 05:00:00  0.011433  0.111111   0.0       0.182093  0.485294
#
#                      templag7  presslag7  wnd_dirlag7  wnd_spdlag7  snowlag7  \
# date
# 2010-01-02 01:00:00       NaN        NaN          NaN          NaN       NaN
# 2010-01-02 02:00:00       NaN        NaN          NaN          NaN       NaN
# 2010-01-02 03:00:00  0.245902   0.527273     0.666667     0.003811  0.000000
# 2010-01-02 04:00:00  0.229508   0.545455     0.666667     0.005332  0.000000
# 2010-01-02 05:00:00  0.229508   0.563636     0.666667     0.008391  0.037037
#
#                      rainlag7
# date
# 2010-01-02 01:00:00       NaN
# 2010-01-02 02:00:00       NaN
# 2010-01-02 03:00:00       0.0
# 2010-01-02 04:00:00       0.0
# 2010-01-02 05:00:00       0.0
